# %%
import numpy as np
from scipy.stats import beta
import matplotlib.pyplot as plt

# Creat data
a = 13
b = 4
data = np.random.beta(a,b, 1000)
data = sorted(data)

plt.figure(1)
x = np.linspace(0.0001, 0.999, 100)
plt.hist(data, bins=20, histtype='bar', color='w', normed=True, label='Real Data')
# Out:
# (array([ 0.18721564,  0.14977251,  0.14977251,  0.4118744 ,  0.93607818,
#          1.04840756,  0.67397629,  2.2091445 ,  2.13425825,  2.54613265,
#          2.73334829,  3.89408523,  4.75527715,  4.04385774,  3.63198334,
#          2.80823454,  2.28403076,  1.87215636,  0.8237488 ,  0.14977251]),
#  array([ 0.44713237,  0.47383954,  0.50054671,  0.52725388,  0.55396105,
#          0.58066822,  0.60737539,  0.63408256,  0.66078973,  0.68749691,
#          0.71420408,  0.74091125,  0.76761842,  0.79432559,  0.82103276,
#          0.84773993,  0.8744471 ,  0.90115427,  0.92786144,  0.95456861,
#          0.98127579]),
#  <a list of 20 Patch objects>)

# %%
# estimate paramter using likihood maximazation and the method of moment
(a, b, _, _) = beta.fit(data)
print a
print b
print "*****"
y = beta.pdf(x, a, b)
plt.plot(x, beta.pdf(x, a, b), 'blue', lw=2, label='Likelihood Maximaztion')
mu = np.mean(data)
var = np.var(data)
a = mu*(mu*(1-mu)/var -1)
b = (1.0 - mu)*(mu*(1-mu)/var -1)
print a
print b
y = beta.pdf(x, a, b)
plt.plot(x, beta.pdf(x, a, b), 'red', lw=2, label='Method of Moment')

plt.legend(ncol=1, prop={'size':10}, bbox_to_anchor=(1, 0.8))
plt.show()
# Out:
# 9.05213688458
# 3.58345148245
# *****
# 13.2673025856
# 4.04254677893
